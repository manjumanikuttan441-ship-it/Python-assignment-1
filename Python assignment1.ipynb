# %%
print("Hello")
# Out:
# Hello

# %%
name=input("Enter your name")
x="Hello "+name
print(x)
# Out:
# Enter your name manju
# Hello manju
# Hello manju

# %%
y= ", Welcome to python programming"
print(x+y)
# Out:
# Hello Manju, Welcome to python programming

# %%
print(x+y)
# Out:
# Hello Manju, Welcome to python programming

# %%
pp="Hello manju, welcome to python programming"
print (pp)
# Out:
# Hello manju, welcome to python programming

# %%
print(pp[0])
print(pp[41])
print(pp[:5])
print(pp[30:])
reverse=pp[::-1]
print(reverse)
# Out:
# H
# g
# Hello
#  programming
# gnimmargorp nohtyp ot emoclew ,ujnam olleH

# %%
print(pp[24:30])
# Out:
# python

# %%
strM="python beginner tutorial"
print(strM.upper())
# Out:
# PYTHON BEGINNER TUTORIAL

# %%
print(strM.lower())
# Out:
# python beginner tutorial

# %%
print(strM.capitalize())
# Out:
# Python beginner tutorial

# %%
print(len(strM))
# Out:
# 24

# %%
print(strM.count("t"))
# Out:
# 3

# %%
print(strM.replace("python","Machine learning"))
# Out:
# Machine learning beginner tutorial

# %%
tuple1=(10,20,30)
tuple2=(40,50,60)
print(tuple1)
print(tuple2)
t_combine=tuple1+tuple2
print(t_combine)
# Out:
# (10, 20, 30)
# (40, 50, 60)
# (10, 20, 30, 40, 50, 60)

# %%
print(t_combine*3)
# Out:
# (10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60, 10, 20, 30, 40, 50, 60)

# %%
print(t_combine [2])
# Out:
# 30

# %%
print(t_combine[:3])
# Out:
# (10, 20, 30)

# %%
print(t_combine[3:])
# Out:
# (40, 50, 60)
